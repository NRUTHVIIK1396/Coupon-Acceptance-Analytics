# %% [markdown]
# ### Will a Customer Accept the Coupon?
#
# **Context**
#
# Imagine driving through town and a coupon is delivered to your cell phone for a restaraunt near where you are driving. Would you accept that coupon and take a short detour to the restaraunt? Would you accept the coupon but use it on a sunbsequent trip? Would you ignore the coupon entirely? What if the coupon was for a bar instead of a restaraunt? What about a coffee house? Would you accept a bar coupon with a minor passenger in the car? What about if it was just you and your partner in the car? Would weather impact the rate of acceptance? What about the time of day?
#
# Obviously, proximity to the business is a factor on whether the coupon is delivered to the driver or not, but what are the factors that determine whether a driver accepts the coupon once it is delivered to them? How would you determine whether a driver is likely to accept a coupon?
#
# **Overview**
#
# The goal of this project is to use what you know about visualizations and probability distributions to distinguish between customers who accepted a driving coupon versus those that did not.
#
# **Data**
#
# This data comes to us from the UCI Machine Learning repository and was collected via a survey on Amazon Mechanical Turk. The survey describes different driving scenarios including the destination, current time, weather, passenger, etc., and then ask the person whether he will accept the coupon if he is the driver. Answers that the user will drive there ‘right away’ or ‘later before the coupon expires’ are labeled as ‘Y = 1’ and answers ‘no, I do not want the coupon’ are labeled as ‘Y = 0’.  There are five different types of coupons -- less expensive restaurants (under \\$20), coffee houses, carry out & take away, bar, and more expensive restaurants (\\$20 - \\$50).

# %% [markdown]
# **Deliverables**
#
# Your final product should be a brief report that highlights the differences between customers who did and did not accept the coupons.  To explore the data you will utilize your knowledge of plotting, statistical summaries, and visualization using Python. You will publish your findings in a public facing github repository as your first portfolio piece.

# %% [markdown]
# ### Data Description
# Keep in mind that these values mentioned below are average values.
#
# The attributes of this data set include:
# 1. User attributes
#     -  Gender: male, female
#     -  Age: below 21, 21 to 25, 26 to 30, etc.
#     -  Marital Status: single, married partner, unmarried partner, or widowed
#     -  Number of children: 0, 1, or more than 1
#     -  Education: high school, bachelors degree, associates degree, or graduate degree
#     -  Occupation: architecture & engineering, business & financial, etc.
#     -  Annual income: less than \\$12500, \\$12500 - \\$24999, \\$25000 - \\$37499, etc.
#     -  Number of times that he/she goes to a bar: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#     -  Number of times that he/she buys takeaway food: 0, less than 1, 1 to 3, 4 to 8 or greater
#     than 8
#     -  Number of times that he/she goes to a coffee house: 0, less than 1, 1 to 3, 4 to 8 or
#     greater than 8
#     -  Number of times that he/she eats at a restaurant with average expense less than \\$20 per
#     person: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#     -  Number of times that he/she goes to a bar: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#
#
# 2. Contextual attributes
#     - Driving destination: home, work, or no urgent destination
#     - Location of user, coupon and destination: we provide a map to show the geographical
#     location of the user, destination, and the venue, and we mark the distance between each
#     two places with time of driving. The user can see whether the venue is in the same
#     direction as the destination.
#     - Weather: sunny, rainy, or snowy
#     - Temperature: 30F, 55F, or 80F
#     - Time: 10AM, 2PM, or 6PM
#     - Passenger: alone, partner, kid(s), or friend(s)
#
#
# 3. Coupon attributes
#     - time before it expires: 2 hours or one day

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import plotly.express as px

# %% [markdown]
# ### Problems
#
# Use the prompts below to get started with your data analysis.
#
# 1. Read in the `coupons.csv` file.

# %%
data = pd.read_csv('../data/coupons.csv')

# %%
data.head()
# Out:
#        destination  passanger weather  temperature  time  \
# 0  No Urgent Place      Alone   Sunny           55   2PM
# 1  No Urgent Place  Friend(s)   Sunny           80  10AM
# 2  No Urgent Place  Friend(s)   Sunny           80  10AM
# 3  No Urgent Place  Friend(s)   Sunny           80   2PM
# 4  No Urgent Place  Friend(s)   Sunny           80   2PM
#
#                   coupon expiration  gender age      maritalStatus  ...  \
# 0        Restaurant(<20)         1d  Female  21  Unmarried partner  ...
# 1           Coffee House         2h  Female  21  Unmarried partner  ...
# 2  Carry out & Take away         2h  Female  21  Unmarried partner  ...
# 3           Coffee House         2h  Female  21  Unmarried partner  ...
# 4           Coffee House         1d  Female  21  Unmarried partner  ...
#
#    CoffeeHouse CarryAway RestaurantLessThan20 Restaurant20To50  \
# 0        never       NaN                  4~8              1~3
# ...

# %% [markdown]
# 2. Investigate the dataset for missing or problematic data.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12684 entries, 0 to 12683
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   destination           12684 non-null  object
#  1   passanger             12684 non-null  object
#  2   weather               12684 non-null  object
#  3   temperature           12684 non-null  int64
#  4   time                  12684 non-null  object
#  5   coupon                12684 non-null  object
#  6   expiration            12684 non-null  object
#  7   gender                12684 non-null  object
#  8   age                   12684 non-null  object
#  9   maritalStatus         12684 non-null  object
#  10  has_children          12684 non-null  int64
#  11  education             12684 non-null  object
#  12  occupation            12684 non-null  object
#  13  income                12684 non-null  object
#  14  car                   108 non-null    object
# ...

# %%
data.tail()
# Out:
#       destination passanger weather  temperature time                 coupon  \
# 12679        Home   Partner   Rainy           55  6PM  Carry out & Take away
# 12680        Work     Alone   Rainy           55  7AM  Carry out & Take away
# 12681        Work     Alone   Snowy           30  7AM           Coffee House
# 12682        Work     Alone   Snowy           30  7AM                    Bar
# 12683        Work     Alone   Sunny           80  7AM      Restaurant(20-50)
#
#       expiration gender age maritalStatus  ...  CoffeeHouse CarryAway  \
# 12679         1d   Male  26        Single  ...        never       1~3
# 12680         1d   Male  26        Single  ...        never       1~3
# 12681         1d   Male  26        Single  ...        never       1~3
# 12682         1d   Male  26        Single  ...        never       1~3
# 12683         2h   Male  26        Single  ...        never       1~3
#
#       RestaurantLessThan20 Restaurant20To50 toCoupon_GEQ5min  \
# ...

# %%
# Get number of rows and columns in the dataframe
data.shape
# Out:
# (12684, 26)

# %%
# Check missing values by feature
data.isnull().sum()
# Out:
# destination                 0
# passanger                   0
# weather                     0
# temperature                 0
# time                        0
# coupon                      0
# expiration                  0
# gender                      0
# age                         0
# maritalStatus               0
# has_children                0
# education                   0
# occupation                  0
# income                      0
# car                     12576
# Bar                       107
# CoffeeHouse               217
# CarryAway                 151
# RestaurantLessThan20      130
# Restaurant20To50          189
# toCoupon_GEQ5min            0
# toCoupon_GEQ15min           0
# toCoupon_GEQ25min           0
# direction_same              0
# direction_opp               0
# Y                           0
# dtype: int64

# %%
# Many values in 'car' column are missing.

# %%
# See the various values that 'car' column can hold.
data['car'].value_counts()
# Out:
# car
# Scooter and motorcycle                      22
# Mazda5                                      22
# do not drive                                22
# crossover                                   21
# Car that is too old to install Onstar :D    21
# Name: count, dtype: int64

# %% [markdown]
# 3. Decide what to do about your missing data -- drop, replace, other...

# %%
# Drop car column as many values are missing and the categories look incorrect.
# For example: The value 'Scooter and motorcycle' should be a new column instead.
data = data.drop(['car'], axis=1)

# %%
# Replace missing values in other columns with mode. This is usually done for categorical features.
data['Bar'] = data['Bar'].fillna(data['Bar'].mode()[0])
data['CoffeeHouse'] = data['CoffeeHouse'].fillna(data['CoffeeHouse'].mode()[0])
data['CarryAway'] = data['CarryAway'].fillna(data['CarryAway'].mode()[0])
data['RestaurantLessThan20'] = data['RestaurantLessThan20'].fillna(data['RestaurantLessThan20'].mode()[0])
data['Restaurant20To50'] = data['Restaurant20To50'].fillna(data['Restaurant20To50'].mode()[0])

# %%
# Check missing values
data.isnull().sum()
# Out:
# destination             0
# passanger               0
# weather                 0
# temperature             0
# time                    0
# coupon                  0
# expiration              0
# gender                  0
# age                     0
# maritalStatus           0
# has_children            0
# education               0
# occupation              0
# income                  0
# Bar                     0
# CoffeeHouse             0
# CarryAway               0
# RestaurantLessThan20    0
# Restaurant20To50        0
# toCoupon_GEQ5min        0
# toCoupon_GEQ15min       0
# toCoupon_GEQ25min       0
# direction_same          0
# direction_opp           0
# Y                       0
# dtype: int64

# %%
# age type is object, expected int64. So look at its values
data['age'].value_counts()
# Out:
# age
# 21         2653
# 26         2559
# 31         2039
# 50plus     1788
# 36         1319
# 41         1093
# 46          686
# below21     547
# Name: count, dtype: int64

# %%
# Replace '50plus' with 55, 'below21' to 18 for it to be suitable to be converted to int64 type.
data['age'] = np.where(data['age'] == '50plus', 55, data['age'])
data['age'] = np.where(data['age'] == 'below21', 18, data['age']).astype(int)

print(data["age"].dtype)
data["age"].value_counts()
# Out:
# int64
# age
# 21    2653
# 26    2559
# 31    2039
# 55    1788
# 36    1319
# 41    1093
# 46     686
# 18     547
# Name: count, dtype: int64

# %%
# Convert income values to integers in the increasing order of range. 
income_mapping = {
    'Less than $12500': 0,
    '$12500 - $24999': 1,
    '$25000 - $37499': 2,
    '$37500 - $49999': 3,
    '$50000 - $62499': 4,
    '$62500 - $74999': 5,
    '$75000 - $87499': 6,
    '$87500 - $99999': 7,
    '$100000 or More': 8
}

data['income'] = data['income'].replace(income_mapping)

print(data['income'].unique())
print(data['income'].dtype)
data['income'].value_counts()
# Out:
# [3 5 1 6 4 2 8 7 0]
# int64
# income
# 2    2013
# 1    1831
# 3    1805
# 8    1736
# 4    1659
# 0    1042
# 7     895
# 6     857
# 5     846
# Name: count, dtype: int64

# %% [markdown]
# 4. What proportion of the total observations chose to accept the coupon?

# %%
# Get the count of number of rows with 'Y'=1. This is the total number of people who accepted the coupon.
accepted_coupon_count = data[data['Y'] == 1].shape[0]
# Get the number of rows.
total_coupon_count = data.shape[0]
# Calculate coupon acceptance proportion
proportion_accepted = accepted_coupon_count / total_coupon_count
print(proportion_accepted)
# Out:
# 0.5684326710816777

# %%
# Get the count of number of rows with 'Y'=0. This is the total number of people who did NOT accept the coupon.
unaccepted_coupon_count = data[data['Y'] == 0].shape[0]
# Calculate coupon unacceptance proportion
proportion_not_accepted = unaccepted_coupon_count / total_coupon_count
print(proportion_not_accepted)
# Out:
# 0.4315673289183223

# %%
# Pie chart to visualize the proportion of total observations who accepted the coupon.
labels = ['Accepted Coupon (Y=1)', 'Did Not Accept Coupon (Y=0)']
sizes = [proportion_accepted * 100, proportion_not_accepted * 100]
colors = ['lightgreen', 'lightcoral']
explode = (0.1, 0)

plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', startangle=70)
plt.axis('equal')
plt.title('Coupon Acceptance proportion')
plt.show()

# %% [markdown]
# 5. Use a bar plot to visualize the `coupon` column.

# %%
# Look at various values of coupon column.
data['coupon'].value_counts()
# Out:
# coupon
# Coffee House             3996
# Restaurant(<20)          2786
# Carry out & Take away    2393
# Bar                      2017
# Restaurant(20-50)        1492
# Name: count, dtype: int64

# %%
# Bar plot to visualize coupon column using seaborn library.
sns.countplot(data=data, x='coupon')

plt.title('Coupons')
plt.xlabel('Coupon Type')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# 6. Use a histogram to visualize the temperature column.

# %%
# Histogram to visualize temperature column using seaborn library.
sns.histplot(data['temperature'], bins=3, kde=True) 
plt.title('Distribution of Temperature')
plt.xlabel('Temperature')
plt.ylabel('Frequency')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# **Investigating the Bar Coupons**
#
# Now, we will lead you through an exploration of just the bar related coupons.
#
# 1. Create a new `DataFrame` that contains just the bar coupons.

# %%
# Dataframe to hold 'Bar' coupon data.
bar_coupon_data = data[data['coupon'] == 'Bar']
bar_coupon_data
# Out:
#            destination  passanger weather  temperature  time coupon  \
# 9      No Urgent Place     Kid(s)   Sunny           80  10AM    Bar
# 13                Home      Alone   Sunny           55   6PM    Bar
# 17                Work      Alone   Sunny           55   7AM    Bar
# 24     No Urgent Place  Friend(s)   Sunny           80  10AM    Bar
# 35                Home      Alone   Sunny           55   6PM    Bar
# ...                ...        ...     ...          ...   ...    ...
# 12663  No Urgent Place  Friend(s)   Sunny           80  10PM    Bar
# 12664  No Urgent Place  Friend(s)   Sunny           55  10PM    Bar
# 12667  No Urgent Place      Alone   Rainy           55  10AM    Bar
# 12670  No Urgent Place    Partner   Rainy           55   6PM    Bar
# 12682             Work      Alone   Snowy           30   7AM    Bar
#
#       expiration  gender  age      maritalStatus  ...  CoffeeHouse CarryAway  \
# ...

# %% [markdown]
# 2. What proportion of bar coupons were accepted?

# %%
# Get the total number of people who got the 'Bar' coupon.
total_bar_coupon_count = bar_coupon_data.shape[0]
# Get the count of number of rows with 'Y'=1. This is the total number of people who accepted the 'Bar' coupon.
# Calculate proportion
accepted_bar_coupon_proportion = bar_coupon_data[bar_coupon_data['Y'] == 1].shape[0] / total_bar_coupon_count
print(accepted_bar_coupon_proportion)
# Out:
# 0.41001487357461575

# %%
# Get the count of number of rows with 'Y'=0. This is the total number of people who did NOT accept the 'Bar' coupon.
# Calculate proportion
unaccepted_bar_coupon_proportion = bar_coupon_data[bar_coupon_data['Y'] == 0].shape[0] / total_bar_coupon_count
print(unaccepted_bar_coupon_proportion)
# Out:
# 0.5899851264253843

# %%
# Pie chart to visualize the proportion of total observationswho received 'Bar' coupon, has accepted it.
labels = ['Accepted Bar Coupon', 'Did Not Accept Bar Coupon']
sizes = [accepted_bar_coupon_proportion * 100, unaccepted_bar_coupon_proportion * 100]
colors = ['lightgreen', 'lightcoral']
explode = (0.1, 0)

plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', startangle=70)
plt.axis('equal')
plt.title('Proportion of Total Observations accepting Bar Coupon')
plt.show()

# %% [markdown]
# 3. Compare the acceptance rate between those who went to a bar 3 or fewer times a month to those who went more.

# %%
bar_coupon_data['Bar'].value_counts()
# Out:
# Bar
# never    851
# less1    570
# 1~3      397
# 4~8      150
# gt8       49
# Name: count, dtype: int64

# %%
# Filter bar coupon dataframe to have only those who went Bar 3 or fewer times a month.
bar_less_than_3 = bar_coupon_data[bar_coupon_data['Bar'].isin(['never', 'less1', '1~3'])]
# Filter bar coupon dataframe to have only those who went Bar more than 3 times a month.
bar_more_than_3 = bar_coupon_data[bar_coupon_data['Bar'].isin(['4~8', 'gt8'])]

bar_less_than_3_count = bar_less_than_3.shape[0]
bar_more_than_3_count = bar_more_than_3.shape[0]

# Coupon acceptance rate among those who went to Bar 3 or fewer times a month. 
bar_acceptance_rate_1 = bar_less_than_3[bar_less_than_3['Y'] == 1].shape[0] / bar_less_than_3_count
# Coupon acceptance rate among those who went to Bar more than 3 times a month. 
bar_acceptance_rate_2 = bar_more_than_3[bar_more_than_3['Y'] == 1].shape[0] / bar_more_than_3_count

print(bar_acceptance_rate_1)
print(bar_acceptance_rate_2)
# Out:
# 0.37073707370737075
# 0.7688442211055276

# %%
# Histogram to visualize the proportion of drivers who accepted and did not accept the coupon,
# among those who went to Bar 3 or fewer times a month
sns.histplot(data=bar_less_than_3, x="Bar", hue='Y', multiple='dodge', shrink=0.8).set(title='3 or fewer visits to Bar')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Histogram to visualize the proportion of drivers who accepted and did not accept the coupon,
# among those who went to Bar more than 3 times a month
sns.histplot(data=bar_more_than_3, x="Bar", hue='Y', multiple='dodge', shrink=0.8).set(title='More than 3 visits to Bar')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# 4. Compare the acceptance rate between drivers who go to a bar more than once a month and are over the age of 25 to the all others.  Is there a difference?

# %%
# Filter bar coupon dataframe to have only those who went Bar more than once a month and are over the age of 25.
bar_coupon_data2 = bar_coupon_data.query('(Bar == "1~3" or Bar == "4~8" or Bar == "gt8") and age > 25')

# Filter bar coupon dataframe to have others apart from the observations in the above dataframe.
bar_coupon_data2_others = bar_coupon_data.query('(Bar == "less1" or Bar == "never") and age <= 25')

# %%
# Coupon acceptance rate among those who went to Bar more than once a month and are over the age of 25. 
bar_acceptance_rate_2 = bar_coupon_data2[bar_coupon_data2["Y"] == 1].shape[0] / bar_coupon_data2.shape[0] * 100
print(bar_acceptance_rate_2)

# Coupon acceptance rate among all others. 
bar_acceptance_rate_2_others = bar_coupon_data2_others[bar_coupon_data2_others["Y"] == 1].shape[0] / bar_coupon_data2_others.shape[0] * 100
print(bar_acceptance_rate_2_others)
# Out:
# 69.52380952380952
# 39.329268292682926

# %%
# Histogram to visualize the proportion of drivers who accepted and did not accept the coupon,
# among those who went to Bar more than once a month and are over the age of 25.
sns.histplot(data=bar_coupon_data2, x="Bar", hue='Y', multiple='dodge', shrink=0.8).set(title='More than one visit to Bar and age above 25')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Histogram to visualize the proportion of drivers who accepted and did not accept the coupon,
# among all others.
sns.histplot(data=bar_coupon_data2_others, x="Bar", hue='Y', multiple='dodge', shrink=0.8).set(title='All others')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# 5. Use the same process to compare the acceptance rate between drivers who go to bars more than once a month and had passengers that were not a kid and had occupations other than farming, fishing, or forestry.

# %%
# Filter bar coupon dataframe to have only those who went Bar more than once a month and had passengers that were not a kid and had occupations other than farming, fishing, or forestry..
bar_coupon_data3 = bar_coupon_data.query('(Bar == "1~3" or Bar == "4~8" or Bar == "gt8") and (passanger != "Kid(s)") and occupation != "Farming Fishing & Forestry"')

# %%
# Histogram to visualize the proportion of drivers who accepted and did not accept the coupon,
# among those who go to bars more than once a month and had passengers that were not a kid and had occupations other than farming, fishing, or forestry.
sns.histplot(data=bar_coupon_data3, x="Bar", hue='Y', multiple='dodge', shrink=0.8).set(title='Bar more than once and had no kid with speicifc occupation')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Coupon acceptance rate among those who go to bars more than once a month and had passengers that were not a kid and had occupations other than farming, fishing, or forestry.. 
bar_acceptance_rate_3 = (bar_coupon_data3[bar_coupon_data3['Y']==1].shape[0] / bar_coupon_data3['Y'].shape[0]) * 100
bar_acceptance_rate_3
# Out:
# 71.32486388384754

# %% [markdown]
# 6. Compare the acceptance rates between those drivers who:
#
# - go to bars more than once a month, had passengers that were not a kid, and were not widowed *OR*
# - go to bars more than once a month and are under the age of 30 *OR*
# - go to cheap restaurants more than 4 times a month and income is less than 50K.

# %%
bar_coupon_data['maritalStatus'].value_counts()
# Out:
# maritalStatus
# Married partner      882
# Single               661
# Unmarried partner    378
# Divorced              75
# Widowed               21
# Name: count, dtype: int64

# %%
# Filter bar coupon dataframe accordingly.
bar_coupon_data4 = bar_coupon_data.query('(Bar == "1~3" or Bar == "4~8" or Bar == "gt8") and (passanger != "Kid(s)") and maritalStatus != "Widowed"')
# Histogram to visualize the acceptance rate in the above dataframe.
sns.histplot(data=bar_coupon_data4, x="Bar", hue='Y', multiple='dodge', shrink=0.8).set_title('Bar more than once, had no kid, not widowed')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Acceptance rate of drivers who go to bars more than once a month, had passengers that were not a kid, and were not widowed
bar_acceptance_rate_4 = (bar_coupon_data4[bar_coupon_data4['Y']==1].shape[0] / bar_coupon_data4.shape[0]) * 100
bar_acceptance_rate_4
# Out:
# 71.32486388384754

# %%
bar_coupon_data5 = bar_coupon_data.query('(Bar == "1~3" or Bar == "4~8" or Bar == "gt8") and age < 30')
sns.histplot(data=bar_coupon_data5, x="Bar", hue='Y', multiple='dodge', shrink=0.8).set_title('Bar more than once, age under 30')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Acceptance rate of drivers who go to bars more than once a month and are under the age of 30
bar_acceptance_rate_5 = (bar_coupon_data5[bar_coupon_data5['Y']==1].shape[0] / bar_coupon_data5.shape[0]) * 100
bar_acceptance_rate_5
# Out:
# 72.17391304347827

# %%
bar_coupon_data6 = bar_coupon_data.query('(RestaurantLessThan20 == "4~8" or RestaurantLessThan20 == "gt8") and income <= 3')
sns.histplot(data=bar_coupon_data6, x="RestaurantLessThan20", hue='Y', multiple='dodge', shrink=0.8).set_title('Restaurant >4, income < 50k')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Acceptance rate of drivers who go to cheap restaurants more than 4 times a month and income is less than 50K.
bar_acceptance_rate_6 = (bar_coupon_data6[bar_coupon_data6['Y']==1].shape[0] / bar_coupon_data6.shape[0]) * 100
bar_acceptance_rate_6
# Out:
# 45.348837209302324

# %%
# Get the acceptance rate of all drivers in the above 3 dataframes together.
filter1 = '((Bar == "1~3" or Bar == "4~8" or Bar == "gt8") and (passanger != "Kid(s)") and maritalStatus != "Widowed")'
filter2 = '((Bar == "1~3" or Bar == "4~8" or Bar == "gt8") and age < 30)'
filter3 = '((RestaurantLessThan20 == "4~8" or RestaurantLessThan20 == "gt8") and income <= 3)'
bar_coupon_data7 = bar_coupon_data.query(filter1 + ' or ' + filter2 + ' or ' + filter3)
bar_acceptance_rate_7 = (bar_coupon_data7[bar_coupon_data7['Y']==1].shape[0] / bar_coupon_data7.shape[0]) * 100
bar_acceptance_rate_7
# Out:
# 58.891752577319586

# %% [markdown]
# 7.  Based on these observations, what do you hypothesize about drivers who accepted the bar coupons?

# %% [markdown]
# Higher acceptance rates are seen in drivers who:
# - go to bar more than 3 times a months
# - had passengers and were not a kid
# - were not widowed
#
# Lower acceptance rate is seen in drivers who:
# - go to cheap restaurants more than 4 times and income less than 50k

# %% [markdown]
# ### Independent Investigation
#
# Using the bar coupon example as motivation, you are to explore one of the other coupon groups and try to determine the characteristics of passengers who accept the coupons.

# %%
coffee_house_coupon_data = data.query('coupon == "Coffee House"')
coffee_house_coupon_data.head()
# Out:
#         destination  passanger weather  temperature  time        coupon  \
# 1   No Urgent Place  Friend(s)   Sunny           80  10AM  Coffee House
# 3   No Urgent Place  Friend(s)   Sunny           80   2PM  Coffee House
# 4   No Urgent Place  Friend(s)   Sunny           80   2PM  Coffee House
# 12  No Urgent Place     Kid(s)   Sunny           55   6PM  Coffee House
# 15             Home      Alone   Sunny           80   6PM  Coffee House
#
#    expiration  gender  age      maritalStatus  ...  CoffeeHouse CarryAway  \
# 1          2h  Female   21  Unmarried partner  ...        never       1~3
# 3          2h  Female   21  Unmarried partner  ...        never       1~3
# 4          1d  Female   21  Unmarried partner  ...        never       1~3
# 12         2h  Female   21  Unmarried partner  ...        never       1~3
# 15         2h  Female   21  Unmarried partner  ...        never       1~3
#
#    RestaurantLessThan20  Restaurant20To50 toCoupon_GEQ5min toCoupon_GEQ15min  \
# ...

# %%
sns.histplot(data=coffee_house_coupon_data, x="CoffeeHouse", hue='Y', multiple='dodge', shrink=0.8).set(title='Coffee house')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Proportion of CoffeHouse coupons accepted
coffe_house_acceptance_rate = coffee_house_coupon_data[coffee_house_coupon_data['Y']==1].shape[0] / coffee_house_coupon_data.shape[0]
coffe_house_acceptance_rate
# Out:
# 0.49924924924924924

# %%
#Proportion of CoffeHouse coupons NOT accepted
coffe_house_unacceptance_rate = coffee_house_coupon_data[coffee_house_coupon_data['Y']==0].shape[0] / coffee_house_coupon_data.shape[0]
coffe_house_unacceptance_rate
# Out:
# 0.5007507507507507

# %%
labels = ['Accepted Coupon (Y=1)', 'Did Not Accept Coupon (Y=0)']
sizes = [coffe_house_acceptance_rate * 100, coffe_house_unacceptance_rate * 100]
colors = ['lightgreen', 'lightcoral']
explode = (0.1, 0)  # explode the 1st slice

plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=90)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Proportion of Total Observations Accepting the Coupon')
plt.show()

# %%
#Acceptance rate of coffeeHouse >= 4
coffee_house_coupon_data2 = coffee_house_coupon_data.query('CoffeeHouse == "4~8" or CoffeeHouse == "gt8"')
sns.histplot(data=coffee_house_coupon_data2, x="CoffeeHouse", hue='Y', multiple='dodge', shrink=0.8).set(title='CoffeeHouse visit > 4')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Proportion of CoffeHouse coupons accepted
coffe_house_acceptance_rate2 = coffee_house_coupon_data2[coffee_house_coupon_data2['Y']==1].shape[0] / coffee_house_coupon_data2.shape[0]
coffe_house_acceptance_rate2
# Out:
# 0.675

# %%
#Acceptance rate of coffeeHouse < 4
coffee_house_coupon_data3 = coffee_house_coupon_data.query('CoffeeHouse == "never" or CoffeeHouse == "less1" or CoffeeHouse == "1~3"')
sns.histplot(data=coffee_house_coupon_data3, x="CoffeeHouse", hue='Y', multiple='dodge', shrink=0.8).set(title='CoffeeHouse visit <= 3')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Proportion of CoffeHouse coupons accepted
coffe_house_acceptance_rate3 = coffee_house_coupon_data3[coffee_house_coupon_data3['Y']==1].shape[0] / coffee_house_coupon_data3.shape[0]
coffe_house_acceptance_rate3
# Out:
# 0.44961489088575096

# %%
#Total accepted
coffee_house_accepted = coffee_house_coupon_data[coffee_house_coupon_data['Y']==1]
sns.histplot(data=coffee_house_accepted, x="age", multiple='dodge', shrink=0.8).set(title='Accepted CoffeeHouse coupons')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Acceptance rate of coffeeHouse < 4 and age < 30
coffee_house_coupon_data4 = coffee_house_coupon_data.query('(CoffeeHouse == "never" or CoffeeHouse == "less1" or CoffeeHouse == "1~3") and age < 30')
sns.histplot(data=coffee_house_coupon_data4, x="CoffeeHouse", hue='Y', multiple='dodge', shrink=0.8).set(title='CoffeeHouse < 4 and age < 30')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Proportion of CoffeHouse coupons accepted
coffe_house_acceptance_rate4 = coffee_house_coupon_data4[coffee_house_coupon_data4['Y']==1].shape[0] / coffee_house_coupon_data4.shape[0]
coffe_house_acceptance_rate4
# Out:
# 0.49007529089664614

# %%
#Acceptance rate of coffeeHouse >= 4 and age < 30
coffee_house_coupon_data5 = coffee_house_coupon_data.query('(CoffeeHouse == "4~8" or CoffeeHouse == "gt8") and age < 30')
sns.histplot(data=coffee_house_coupon_data5, x="CoffeeHouse", hue='Y', multiple='dodge', shrink=0.8).set(title='CoffeeHouse visit >= 4 and age < 30')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Proportion of CoffeHouse coupons accepted
coffe_house_acceptance_rate5 = coffee_house_coupon_data5[coffee_house_coupon_data5['Y']==1].shape[0] / coffee_house_coupon_data5.shape[0]
coffe_house_acceptance_rate5
# Out:
# 0.6880952380952381

# %%
# create sns heatmap to co-relate maritalStatus and CoffeeHouse visits
sns.heatmap(pd.crosstab(coffee_house_coupon_data.maritalStatus, coffee_house_coupon_data.CoffeeHouse, normalize=True), annot=False)
# Out:
# <Axes: xlabel='CoffeeHouse', ylabel='maritalStatus'>

# %%
#Acceptance rate of coffeeHouse < 4 and MaritalStatus is Single or Married partner
coffee_house_coupon_data6 = coffee_house_coupon_data.query('(CoffeeHouse == "never" or CoffeeHouse == "less1" or CoffeeHouse == "1~3") and (maritalStatus == "Single" or maritalStatus == "Married partner")')
sns.histplot(data=coffee_house_coupon_data6, x="CoffeeHouse", hue='Y', multiple='dodge', shrink=0.8).set(title='CoffeeHouse visits < 4, single or married')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Proportion of CoffeHouse coupons accepted
coffe_house_acceptance_rate6 = coffee_house_coupon_data6[coffee_house_coupon_data6['Y']==1].shape[0] / coffee_house_coupon_data6.shape[0]
coffe_house_acceptance_rate6
# Out:
# 0.454733360892931

# %%
#Acceptance rate of coffeeHouse >= 4 and MaritalStatus is Single or Married partner
coffee_house_coupon_data7 = coffee_house_coupon_data.query('(CoffeeHouse == "4~8" or CoffeeHouse == "gt8") and (maritalStatus == "Single" or maritalStatus == "Married partner")')
sns.histplot(data=coffee_house_coupon_data7, x="CoffeeHouse", hue='Y', multiple='dodge', shrink=0.8).set(title='CoffeeHouse > 4, single or married')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Proportion of CoffeHouse coupons accepted
coffe_house_acceptance_rate7 = coffee_house_coupon_data7[coffee_house_coupon_data7['Y']==1].shape[0] / coffee_house_coupon_data7.shape[0]
coffe_house_acceptance_rate7
# Out:
# 0.6845238095238095

# %%
# CoffeeHouse coupon findings
#     Half of the coffeeHouse coupons get accepted
#     Drivers who go to CoffeeHouse more than 4 times a month have higher coupon acceptance rate than those who go less
#     CoffeeHouse coupon acceptance rate is usually higher among younger adults (age < 30)
#     Among younger adults (age < 30), coffeeHouse coupon acceptance rate is higher by drivers who visit more than 4 times a month
#     Widowed and Divorced have very low coffeehouse coupon accptance rate
#     Of the single/married drivers, the coupon acceptance rate is higher among those who visit more than 3 times a month
